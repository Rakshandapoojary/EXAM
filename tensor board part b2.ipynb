# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
 
])

# %%
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
tf_callbacks = tf.keras.callbacks.TensorBoard(log_dir = "logs/fit" , histogram_freq = 1)

# %%
history=model.fit(x_train, y_train,validation_data=(x_test,y_test), epochs=10, callbacks = tf_callbacks)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1040 - accuracy: 0.9700 - val_loss: 0.1019 - val_accuracy: 0.9688
# Epoch 2/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0921 - accuracy: 0.9734 - val_loss: 0.0957 - val_accuracy: 0.9708
# Epoch 3/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0820 - accuracy: 0.9763 - val_loss: 0.0899 - val_accuracy: 0.9726
# Epoch 4/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0746 - accuracy: 0.9784 - val_loss: 0.0837 - val_accuracy: 0.9748
# Epoch 5/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0670 - accuracy: 0.9802 - val_loss: 0.0798 - val_accuracy: 0.9749
# Epoch 6/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0606 - accuracy: 0.9825 - val_loss: 0.0776 - val_accuracy: 0.9766
# Epoch 7/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0561 - accuracy: 0.9835 - val_loss: 0.0757 - val_accuracy: 0.9754
# Epoch 8/10
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0516 - accuracy: 0.9849 - val_loss: 0.0731 - val_accuracy: 0.9766
# Epoch 9/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0459 - accuracy: 0.9871 - val_loss: 0.0689 - val_accuracy: 0.9780
# Epoch 10/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0431 - accuracy: 0.9877 - val_loss: 0.0689 - val_accuracy: 0.9769

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir logs/fit

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
